# %% [markdown]
# ## Food and Agriculture Organization of the United Nations

# %% [markdown]
# ### [Production: Crops and livestock products](https://www.fao.org/faostat/en/#data) ([Bulk Downloads](https://www.fao.org/faostat/en/#data/QCL))

# %%
import pandas as pd

# Load the CSV file (adjust the path to the location of your downloaded file)
df_prod_crops_europe = pd.read_csv('FAOSTAT/Production_Crops_Livestock_E_Europe_NOFLAG.csv')
df_prod_crops_oceania = pd.read_csv('FAOSTAT/Production_Crops_Livestock_E_Oceania_NOFLAG.csv')
df_prod_crops_africa = pd.read_csv('FAOSTAT/Production_Crops_Livestock_E_Africa_NOFLAG.csv')
df_prod_crops_americas = pd.read_csv('FAOSTAT/Production_Crops_Livestock_E_Americas_NOFLAG.csv')
df_prod_crops_asia = pd.read_csv('FAOSTAT/Production_Crops_Livestock_E_Asia_NOFLAG.csv')

# Display the first few rows to understand the structure
df_prod_crops = df_prod_crops_asia
df_prod_crops.head(5)
# Out:
#    Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0          2            '004  Afghanistan        221          '01371
# 1          2            '004  Afghanistan        221          '01371
# 2          2            '004  Afghanistan        221          '01371
# 3          2            '004  Afghanistan        711          '01654
# 4          2            '004  Afghanistan        711          '01654
#
#                                                 Item  Element Code  \
# 0                                  Almonds, in shell          5312
# 1                                  Almonds, in shell          5412
# 2                                  Almonds, in shell          5510
# 3  Anise, badian, coriander, cumin, caraway, fenn...          5312
# 4  Anise, badian, coriander, cumin, caraway, fenn...          5412
#
#           Element   Unit  Y1961  ...    Y2014    Y2015    Y2016    Y2017  \
# ...

# %%
df_prod_crops['Area'].unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei Darussalam', 'Cambodia', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Cyprus', "Democratic People's Republic of Korea", 'Georgia',
#        'India', 'Indonesia', 'Iran (Islamic Republic of)', 'Iraq',
#        'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Lebanon', 'Malaysia',
#        'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'Oman', 'Pakistan',
#        'Palestine', 'Philippines', 'Qatar', 'Republic of Korea',
#        'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syrian Arab Republic',
#        'Tajikistan', 'Thailand', 'Timor-Leste', 'Türkiye', 'Turkmenistan',
#        'United Arab Emirates', 'Uzbekistan', 'Viet Nam', 'Yemen'],
#       dtype=object)

# %%
df_prod_crops['Item'].unique()
# Out:
# array(['Almonds, in shell',
#        'Anise, badian, coriander, cumin, caraway, fennel and juniper berries, raw',
#        'Apples', 'Apricots', 'Asses', 'Barley',
#        'Butter and ghee of sheep milk', 'Butter of cow milk',
#        'Buttermilk, dry', 'Camels', 'Cantaloupes and other melons',
#        'Cattle', 'Cattle fat, unrendered',
#        'Cheese from milk of goats, fresh or processed',
#        'Cheese from milk of sheep, fresh or processed', 'Chickens',
#        'Cotton lint, ginned', 'Cotton seed', 'Cottonseed oil',
#        'Edible offal of cattle, fresh, chilled or frozen',
#        'Edible offal of goat, fresh, chilled or frozen',
#        'Edible offal of sheep, fresh, chilled or frozen',
#        'Edible offals of camels and other camelids, fresh, chilled or frozen',
#        'Fat of camels', 'Figs', 'Game meat, fresh, chilled or frozen',
#        'Goat fat, unrendered', 'Goats', 'Grapes',
#        'Hen eggs in shell, fresh', 'Horses', 'Linseed', 'Maize (corn)',
# ...

# %%
df_prod_crops['Element'].unique()
# Out:
# array(['Area harvested', 'Yield', 'Production', 'Stocks',
#        'Producing Animals/Slaughtered', 'Yield/Carcass Weight', 'Laying',
#        'Milk Animals'], dtype=object)

# %%
df_prod_crops['Unit'].unique()
# Out:
# array(['ha', 'kg/ha', 't', 'An', '1000 An', 'No/An', 'g/An', '1000 No',
#        'kg/An', 'No'], dtype=object)

# %%
from matplotlib import pyplot as plt

area = 'Syrian Arab Republic'
item = 'Rice'
element = 'Production'
unit = 't'
start_year = 1961
end_year = 2023

df_prod_crops_syria = df_prod_crops[(df_prod_crops['Area'] == area) & (df_prod_crops['Item'] == item) & (df_prod_crops['Element'] == element)]

# Step 5: Select the year columns (Y1961 to Y2023)
year_columns = [col for col in df_prod_crops_syria.columns if col.startswith('Y')]

# Step 6: Extract the production data for years (Y1961 to Y2023)
df_years = df_production_tons[year_columns].iloc[0]  # Take the first row (only one row for Syrian Arab Republic)

# Step 7: Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df_years.index, df_years.values, marker='o', color='b', linestyle='-', linewidth=2)

# Set labels and title
plt.xlabel('Year')
plt.ylabel(f'Production ({unit})')
plt.title(f'Rice Production in Syrian Arab Republic ({start_year}-{end_year})')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Areas to loop through
areas = ['Syrian Arab Republic', 'Afghanistan']
items = ['Beans, dry', 'Cattle', 'Rice', 'Wheat', 'Meat, Total']
elements = ['Area harvested', 'Production', 'Stocks']

# Loop through each area
for area in areas:
    for item in items:
        for element in elements:
            #for unit in df_prod_crops['Unit'].unique():
                #print(f"\nAnalyzing {area} - {item} - {element} - {unit}...\n")
                
                # Filter data for the current area, item, element, and unit
                df_filtered = df_prod_crops[(df_prod_crops['Area'] == area) & 
                                             (df_prod_crops['Item'] == item) & 
                                             (df_prod_crops['Element'] == element) ]

                unit = df_filtered['Unit'].unique()[0] if not df_filtered.empty else None
                
                # Select the year columns (Y1961 to Y2023)
                year_columns = [col for col in df_filtered.columns if col.startswith('Y') and start_year <= int(col[1:]) <= end_year]
                
                if not df_filtered.empty and year_columns:
                    # Extract the data for years (Y1961 to Y2023)
                    df_years = df_filtered[year_columns].iloc[0]

                    # Plot the data
                    plt.figure(figsize=(10, 6))
                    plt.plot(df_years.index, df_years.values, marker='o', color='b', linestyle='-', linewidth=2)
                    
                    # Set labels and title
                    plt.xlabel('Year', labelpad=20)
                    plt.ylabel(f'{element} ({unit})')
                    plt.title(f'{item} - {element} in {area} ({unit}) ({start_year}-{end_year})')
                    
                    # Rotate the x-axis labels for better readability
                    plt.xticks(rotation=90)
                    
                    # Show the plot
                    plt.tight_layout()
                    plt.show()

                else:
                    #print(f"No data available for {area}, {item}, {element}, {unit}.\n")
                    print("")
    
    print(f"\nFinished analyzing data for {area}.\n")
# Out:
# Finished analyzing data for Syrian Arab Republic.
# Finished analyzing data for Afghanistan.

# %%
# Load the CSV file (adjust the path to the location of your downloaded file)
df_prod_values_europe = pd.read_csv('FAOSTAT/Value_of_Production_E_Europe_NOFLAG.csv')
df_prod_values_oceania = pd.read_csv('FAOSTAT/Value_of_Production_E_Oceania_NOFLAG.csv')
df_prod_values_africa = pd.read_csv('FAOSTAT/Value_of_Production_E_Africa_NOFLAG.csv')
df_prod_values_americas = pd.read_csv('FAOSTAT/Value_of_Production_E_Americas_NOFLAG.csv')
df_prod_values_asia = pd.read_csv('FAOSTAT/Value_of_Production_E_Asia_NOFLAG.csv')

# Display the first few rows to understand the structure
df_prod_values = df_prod_values_asia
df_prod_values.head(5)
# Out:
#    Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0          2            '004  Afghanistan        221          '01371
# 1          2            '004  Afghanistan        221          '01371
# 2          2            '004  Afghanistan        221          '01371
# 3          2            '004  Afghanistan        711          '01654
# 4          2            '004  Afghanistan        515          '01341
#
#                                                 Item  Element Code  \
# 0                                  Almonds, in shell           152
# 1                                  Almonds, in shell            56
# 2                                  Almonds, in shell            55
# 3  Anise, badian, coriander, cumin, caraway, fenn...           152
# 4                                             Apples           152
#
#                                              Element       Unit   Y1961  ...  \
# ...

# %%
df_prod_values['Area'].unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei Darussalam', 'Cambodia', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Cyprus', "Democratic People's Republic of Korea", 'Georgia',
#        'India', 'Indonesia', 'Iran (Islamic Republic of)', 'Iraq',
#        'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Lebanon', 'Malaysia',
#        'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'Oman', 'Pakistan',
#        'Palestine', 'Philippines', 'Qatar', 'Republic of Korea',
#        'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syrian Arab Republic',
#        'Tajikistan', 'Thailand', 'Timor-Leste', 'Türkiye', 'Turkmenistan',
#        'United Arab Emirates', 'Uzbekistan', 'Viet Nam', 'Yemen'],
#       dtype=object)

# %%
df_prod_values['Item'].unique()
# Out:
# array(['Almonds, in shell',
#        'Anise, badian, coriander, cumin, caraway, fennel and juniper berries, raw',
#        'Apples', 'Apricots', 'Barley', 'Cantaloupes and other melons',
#        'Figs', 'Game meat, fresh, chilled or frozen', 'Grapes',
#        'Hen eggs in shell, fresh', 'Linseed', 'Maize (corn)',
#        'Meat of camels, fresh or chilled (indigenous)',
#        'Meat of cattle with the bone, fresh or chilled (indigenous)',
#        'Meat of chickens, fresh or chilled (indigenous)',
#        'Meat of goat, fresh or chilled (indigenous)',
#        'Meat of sheep, fresh or chilled (indigenous)', 'Millet',
#        'Mustard seed', 'Natural honey', 'Olives',
#        'Onions and shallots, dry (excluding dehydrated)', 'Oranges',
#        'Other berries and fruits of the genus vaccinium n.e.c.',
#        'Other citrus fruit, n.e.c.', 'Other fruits, n.e.c.',
#        'Other nuts (excluding wild edible nuts and groundnuts), in shell, n.e.c.',
# ...

# %%
df_prod_values['Element'].unique()
# Out:
# array(['Gross Production Value (constant 2014-2016 thousand I$)',
#        'Gross Production Value (current thousand SLC)',
#        'Gross Production Value (constant 2014-2016 thousand SLC)',
#        'Gross Production Value (current thousand US$)',
#        'Gross Production Value (constant 2014-2016 thousand US$)'],
#       dtype=object)

# %%
df_prod_values['Unit'].unique()
# Out:
# array(['1000 Int$', '1000 SLC', '1000 USD'], dtype=object)

# %%
area = 'Syrian Arab Republic'
item = 'Rice'
element = 'Gross Production Value (constant 2014-2016 thousand I$)'
unit = '1000 Int$'
df_prod_values_syria = df_prod_values[(df_prod_values['Area'] == area) & (df_prod_values['Item'] == item) & (df_prod_values['Element'] == element)]

# Step 5: Select the year columns (Y1961 to Y2023)
year_columns = [col for col in df_prod_values_syria.columns if col.startswith('Y')]

# Step 6: Extract the production data for years (Y1961 to Y2023)
df_years = df_prod_values_syria[year_columns].iloc[0]  # Take the first row (only one row for Syrian Arab Republic)

# Step 7: Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df_years.index, df_years.values, marker='o', color='b', linestyle='-', linewidth=2)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Gross Production Value (1000 Int$)')
plt.title(f'Rice Gross Production Value in Syrian Arab Republic ({start_year}-{end_year})')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Areas to loop through
areas = ['Syrian Arab Republic', 'Afghanistan']
items = ['Beans, dry', 'Cattle', 'Rice', 'Wheat', 'Meat, Total']
elements = ['Gross Production Value (constant 2014-2016 thousand I$)']
start_year = 1961
end_year = 2023

# Loop through each area
for area in areas:
    for item in items:
        for element in elements:
            #for unit in df_prod_crops['Unit'].unique():
                #print(f"\nAnalyzing {area} - {item} - {element} - {unit}...\n")
                
                # Filter data for the current area, item, element, and unit
                df_filtered = df_prod_values[(df_prod_values['Area'] == area) & 
                                             (df_prod_values['Item'] == item) & 
                                             (df_prod_values['Element'] == element) ]

                unit = df_filtered['Unit'].unique()[0] if not df_filtered.empty else None
                
                # Select the year columns (Y1961 to Y2023)
                year_columns = [col for col in df_filtered.columns if col.startswith('Y') and start_year <= int(col[1:]) <= end_year]
                
                if not df_filtered.empty and year_columns:
                    # Extract the data for years (Y1961 to Y2023)
                    df_years = df_filtered[year_columns].iloc[0]

                    # Plot the data
                    plt.figure(figsize=(10, 6))
                    plt.plot(df_years.index, df_years.values, marker='o', color='b', linestyle='-', linewidth=2)
                    
                    # Set labels and title
                    plt.xlabel('Year', labelpad=20)
                    plt.ylabel(f'{element} ({unit})')
                    plt.title(f'{item} - {element} in {area} ({unit}) ({start_year}-{end_year})')
                    
                    # Rotate the x-axis labels for better readability
                    plt.xticks(rotation=90)
                    
                    # Show the plot
                    plt.tight_layout()
                    plt.show()

                else:
                    #print(f"No data available for {area}, {item}, {element}, {unit}.\n")
                    print("")
    
    print(f"\nFinished analyzing data for {area}.\n")
# Out:
# Finished analyzing data for Syrian Arab Republic.
# Finished analyzing data for Afghanistan.

# %%
# Load the CSV file (adjust the path to the location of your downloaded file)
df_population_europe = pd.read_csv('FAOSTAT/Population_E_Europe_NOFLAG.csv')
df_population_oceania = pd.read_csv('FAOSTAT/Population_E_Oceania_NOFLAG.csv')
df_population_africa = pd.read_csv('FAOSTAT/Population_E_Africa_NOFLAG.csv')
df_population_americas = pd.read_csv('FAOSTAT/Population_E_Americas_NOFLAG.csv')
df_population_asia = pd.read_csv('FAOSTAT/Population_E_Asia_NOFLAG.csv')

# Display the first few rows to understand the structure
df_population = df_population_asia
df_population.head(5)
# Out:
#    Area Code Area Code (M49)         Area  Item Code  \
# 0          2            '004  Afghanistan       3010
# 1          2            '004  Afghanistan       3010
# 2          2            '004  Afghanistan       3010
# 3          2            '004  Afghanistan       3010
# 4          2            '004  Afghanistan       3010
#
#                         Item  Element Code                        Element  \
# 0  Population - Est. & Proj.           511  Total Population - Both sexes
# 1  Population - Est. & Proj.           512        Total Population - Male
# 2  Population - Est. & Proj.           513      Total Population - Female
# 3  Population - Est. & Proj.           551               Rural population
# 4  Population - Est. & Proj.           561               Urban population
#
#       Unit     Y1950     Y1951  ...       Y2091       Y2092       Y2093  \
# 0  1000 No  7776.176  7879.339  ...  124110.001  124854.161  125589.411
# ...

# %%
df_population['Area'].unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei Darussalam', 'Cambodia', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Cyprus', "Democratic People's Republic of Korea", 'Georgia',
#        'India', 'Indonesia', 'Iran (Islamic Republic of)', 'Iraq',
#        'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Lebanon', 'Malaysia',
#        'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'Oman', 'Pakistan',
#        'Palestine', 'Philippines', 'Qatar', 'Republic of Korea',
#        'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syrian Arab Republic',
#        'Tajikistan', 'Thailand', 'Timor-Leste', 'Türkiye', 'Turkmenistan',
#        'United Arab Emirates', 'Uzbekistan', 'Viet Nam', 'Yemen'],
#       dtype=object)

# %%
df_population['Item'].unique()
# Out:
# array(['Population - Est. & Proj.'], dtype=object)

# %%
df_population['Element'].unique()
# Out:
# array(['Total Population - Both sexes', 'Total Population - Male',
#        'Total Population - Female', 'Rural population',
#        'Urban population'], dtype=object)

# %%
df_population['Unit'].unique()
# Out:
# array(['1000 No'], dtype=object)

# %%
area = 'Syrian Arab Republic'
element = 'Total Population - Both sexes'
unit = '1000 No'
df_population_syria = df_population[(df_population['Area'] == area) & (df_population['Element'] == element)]

# Step 5: Select the year columns (Y1961 to Y2023)
year_columns = [col for col in df_population_syria.columns if col.startswith('Y') and start_year <= int(col[1:]) <= end_year]

# Step 6: Extract the production data for years (Y1961 to Y2023)
df_years = df_population_syria[year_columns].iloc[0]  # Take the first row (only one row for Syrian Arab Republic)

# Step 7: Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df_years.index, df_years.values, marker='o', color='b', linestyle='-', linewidth=2)

# Set labels and title
plt.xlabel('Year')
plt.ylabel(f'Total Population - Both sexes ({unit})')
plt.title(f'Total Population in Syrian Arab Republic ({start_year}-{end_year})')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Areas to loop through
areas = ['Syrian Arab Republic', 'Afghanistan']
elements = ['Total Population - Both sexes']

# Loop through each area
for area in areas:
    for element in elements:
                
        # Filter data for the current area, item, element, and unit
        df_filtered = df_population[(df_population['Area'] == area) & 
                                    (df_population['Element'] == element) ]

        unit = df_filtered['Unit'].unique()[0] if not df_filtered.empty else None
                
        # Select the year columns (Y1961 to Y2023)
        year_columns = [col for col in df_filtered.columns if col.startswith('Y') and start_year <= int(col[1:]) <= end_year]
                
        if not df_filtered.empty and year_columns:
            # Extract the data for years (Y1961 to Y2023)
            df_years = df_filtered[year_columns].iloc[0]

            # Plot the data
            plt.figure(figsize=(10, 6))
            plt.plot(df_years.index, df_years.values, marker='o', color='b', linestyle='-', linewidth=2)
                    
            # Set labels and title
            plt.xlabel('Year', labelpad=20)
            plt.ylabel(f'{element} ({unit})')
            plt.title(f'{element} in {area} ({unit}) ({start_year}-{end_year})')
                    
            # Rotate the x-axis labels for better readability
            plt.xticks(rotation=90)
                    
            # Show the plot
            plt.tight_layout()
            plt.show()

        else:
            #print(f"No data available for {area}, {item}, {element}, {unit}.\n")
            print("")
    
    print(f"\nFinished analyzing data for {area}.\n")
# Out:
# Finished analyzing data for Syrian Arab Republic.
# Finished analyzing data for Afghanistan.
